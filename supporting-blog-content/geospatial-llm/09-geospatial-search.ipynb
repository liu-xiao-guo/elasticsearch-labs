# %% [markdown]
# # Install and Connect
#
# To get started, we'll need to connect to our Elastic deployment using the Python client.

# %%
# !pip install -qU elasticsearch requests openai python-dotenv langchain-openai
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %% [markdown]
# Next, we need to import the modules we need.

# %%
from dotenv import load_dotenv
import os
from elasticsearch import Elasticsearch, helpers, exceptions
from elasticsearch.helpers import BulkIndexError
import time
import json as JSON

# %% [markdown]
# Now we can instantiate the Python Elasticsearch client. Then we create a client object that instantiates an instance of the Elasticsearch class

# %%
load_dotenv()

ES_USER = os.getenv("ES_USER")
ES_PASSWORD = os.getenv("ES_PASSWORD")
ES_ENDPOINT = os.getenv("ES_ENDPOINT")

url = f"https://{ES_USER}:{ES_PASSWORD}@{ES_ENDPOINT}:9200"
print(url)

client = Elasticsearch(url, ca_certs = "./http_ca.crt", verify_certs = True)
# Out:
# https://elastic:=VnaMJck+DbYXpHR1Fch@localhost:9200

# %%
print(client.info())
# Out:
# {'name': 'liuxgm.local', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'JXoZ_Xu-QnasteO4AWnVvQ', 'version': {'number': '8.13.4', 'build_flavor': 'default', 'build_type': 'tar', 'build_hash': 'da95df118650b55a500dcc181889ac35c6d8da7c', 'build_date': '2024-05-06T22:04:45.107454559Z', 'build_snapshot': False, 'lucene_version': '9.10.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %% [markdown]
# Refer to https://www.elastic.co/guide/en/elasticsearch/client/python-api/current/connecting.html#connect-self-managed-new to learn how to connect to a self-managed deployment.
#
# Read https://www.elastic.co/guide/en/elasticsearch/client/python-api/current/connecting.html#connect-self-managed-new to learn how to connect using API keys.

# %% [markdown]
# # Download and Deploy ELSER Model
#
# In this example, we are going to download and deploy the ELSER model in our ML node. Make sure you have an ML node in order to run the ELSER model.

# %%
# delete model if already downloaded and deployed
try:
    client.ml.delete_trained_model(model_id=".elser_model_2", force=True)
    print("Model deleted successfully, We will proceed with creating one")
except exceptions.NotFoundError:
    print("Model doesn't exist, but We will proceed with creating one")

# Creates the ELSER model configuration. Automatically downloads the model if it doesn't exist.
client.ml.put_trained_model(
    model_id=".elser_model_2", input={"field_names": ["text_field"]}
)
# Out:
# Model deleted successfully, We will proceed with creating one
# ObjectApiResponse({'model_id': '.elser_model_2', 'model_type': 'pytorch', 'model_package': {'packaged_model_id': 'elser_model_2', 'model_repository': 'https://ml-models.elastic.co', 'minimum_version': '11.0.0', 'size': 438123914, 'sha256': '2e0450a1c598221a919917cbb05d8672aed6c613c028008fedcd696462c81af0', 'metadata': {}, 'tags': [], 'vocabulary_file': 'elser_model_2.vocab.json'}, 'created_by': 'api_user', 'version': '12.0.0', 'create_time': 1717137482538, 'model_size_bytes': 0, 'estimated_operations': 0, 'license_level': 'platinum', 'description': 'Elastic Learned Sparse EncodeR v2', 'tags': ['elastic'], 'metadata': {}, 'input': {'field_names': ['text_field']}, 'inference_config': {'text_expansion': {'vocabulary': {'index': '.ml-inference-native-000002'}, 'tokenization': {'bert': {'do_lower_case': True, 'with_special_tokens': True, 'max_sequence_length': 512, 'truncate': 'first', 'span': -1}}}}, 'location': {'index': {'name': '.ml-inference-native-000002'}}})

# %% [markdown]
# The above command will download the ELSER model. This will take a few minutes to complete. Use the following command to check the status of the model download.

# %%
while True:
    status = client.ml.get_trained_models(
        model_id=".elser_model_2", include="definition_status"
    )

    if status["trained_model_configs"][0]["fully_defined"]:
        print("ELSER Model is downloaded and ready to be deployed.")
        break
    else:
        print("ELSER Model is downloaded but not ready to be deployed.")
    time.sleep(5)
# Out:
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded but not ready to be deployed.
# ELSER Model is downloaded and ready to be deployed.

# %% [markdown]
# Once the model is downloaded, we can deploy the model in our ML node. Use the following command to deploy the model.

# %%
# Start trained model deployment if not already deployed
client.ml.start_trained_model_deployment(
    model_id=".elser_model_2", number_of_allocations=1, wait_for="starting"
)

while True:
    status = client.ml.get_trained_models_stats(
        model_id=".elser_model_2",
    )
    if status["trained_model_stats"][0]["deployment_stats"]["state"] == "started":
        print("ELSER Model has been successfully deployed.")
        break
    else:
        print("ELSER Model is currently being deployed.")
    time.sleep(5)
# Out:
# ELSER Model is currently being deployed.
# ELSER Model has been successfully deployed.

# %% [markdown]
# ### Indexing Documents with ELSER
# In order to use ELSER on our Elastic Cloud deployment we'll need to create an ingest pipeline that contains an inference processor that runs the ELSER model. Let's add that pipeline using the [put_pipeline](https://www.elastic.co/guide/en/elasticsearch/reference/master/put-pipeline-api.html) method.

# %%
client.ingest.put_pipeline(
    id="elser-ingest-pipeline",
    description="Ingest pipeline for ELSER",
    processors=[
        {"html_strip": {"field": "name", "ignore_failure": True}},
        {"html_strip": {"field": "description", "ignore_failure": True}},
        {"html_strip": {"field": "amenities", "ignore_failure": True}},
        {"html_strip": {"field": "host_about", "ignore_failure": True}},
        {
            "inference": {
                "model_id": ".elser_model_2",
                "input_output": [
                    {"input_field": "name", "output_field": "name_embedding"}
                ],
                "ignore_failure": True,
            }
        },
        {
            "inference": {
                "model_id": ".elser_model_2",
                "input_output": [
                    {
                        "input_field": "description",
                        "output_field": "description_embedding",
                    }
                ],
                "ignore_failure": True,
            }
        },
        {
            "inference": {
                "model_id": ".elser_model_2",
                "input_output": [
                    {"input_field": "amenities", "output_field": "amenities_embedding"}
                ],
                "ignore_failure": True,
            }
        },
        {
            "inference": {
                "model_id": ".elser_model_2",
                "input_output": [
                    {
                        "input_field": "host_about",
                        "output_field": "host_about_embedding",
                    }
                ],
                "ignore_failure": True,
            }
        },
    ],
)
# Out:
# ObjectApiResponse({'acknowledged': True})

# %% [markdown]
# ### Preparing the AirBnB Listings
#
# Next up we need to prepare the index. We will map everything as keyword unless otherwise specified. We will also map the `name` and the `description` of the listing as `sparse_vectors` using ELSER.

# %%
client.indices.delete(index="airbnb-listings", ignore_unavailable=True)
client.indices.create(
    index="airbnb-listings",
    settings={"index": {"default_pipeline": "elser-ingest-pipeline"}},
    mappings={
        "dynamic_templates": [
            {
                "stringsaskeywords": {
                    "match": "*",
                    "match_mapping_type": "string",
                    "mapping": {"type": "keyword"},
                }
            }
        ],
        "properties": {
            "host_about_embedding": {"type": "sparse_vector"},
            "amenities_embedding": {"type": "sparse_vector"},
            "description_embedding": {"type": "sparse_vector"},
            "name_embedding": {"type": "sparse_vector"},
            "location": {"type": "geo_point"},
        },
    },
)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'airbnb-listings'})

# %% [markdown]
# ### Downloading the AirBnB data
#
# next up we will download the AirBnB listings csv and upload it to Elasticsearch. This can take a couple of minutes! The AirBnB listing is roughly ~80mb of CSV expanded and roughly 40.000 documents. In the code below we added an if condition to only process the first 5.000 documents.

# %%
import requests
import gzip
import shutil
import csv

# Download the CSV file
# url = "https://data.insideairbnb.com/united-states/ny/new-york-city/2024-03-07/data/listings.csv.gz"
# response = requests.get(url, stream=True)

# Save the downloaded file
#with open("listings.csv.gz", "wb") as file:
#    shutil.copyfileobj(response.raw, file)

# Unpack the CSV file
#with gzip.open("./listings.csv.gz", "rb") as file_in:
#    with open("listings.csv", "wb") as file_out:
#        shutil.copyfileobj(file_in, file_out)

def remove_empty_fields(data):
    empty_fields = []
    # Iterate over the dictionary items
    for key, value in data.items():
        # Check if the value is empty (None, empty string, empty list, etc.)
        if not value:
            empty_fields.append(key)
    # Remove empty fields from the dictionary
    for key in empty_fields:
        del data[key]
    return data


def prepare_documents():
    with open("./listings.csv", "r", encoding="utf-8") as file:
        reader = csv.DictReader(file, delimiter=",")
        # we are going to only add the first 5.000 listings.
        limit = 5000
        for index, row in enumerate(reader):
            if index >= limit:
                break
            if index % 250 == 0:
                print(f"Processing document {index}")
            row["location"] = {
                "lat": float(row["latitude"]),
                "lon": float(row["longitude"]),
            }
            row = remove_empty_fields(row)
            yield {
                "_index": "airbnb-listings",
                "_source": dict(row),
            }

# Note: A bigger chunk_size might cause "connection timeout error"
helpers.bulk(client, prepare_documents(), chunk_size=10)
# Out:
# Processing document 0
# Processing document 250
# Processing document 500
# Processing document 750
# Processing document 1000
# Processing document 1250
# Processing document 1500
# Processing document 1750
# Processing document 2000
# Processing document 2250
# Processing document 2500
# Processing document 2750
# Processing document 3000
# Processing document 3250
# Processing document 3500
# Processing document 3750
# Processing document 4000
# Processing document 4250
# Processing document 4500
# Processing document 4750
# (5000, [])

# %% [markdown]
# ### Prepare the MTA subway stations index
#
# We need to prepare the index and make sure that we treat the geo location as a geo location.

# %%
client.indices.delete(index="mta-stations", ignore_unavailable=True)
client.indices.create(
    index="mta-stations",
    mappings={
        "dynamic_templates": [
            {
                "stringsaskeywords": {
                    "match": "*",
                    "match_mapping_type": "string",
                    "mapping": {"type": "keyword"},
                }
            }
        ],
        "properties": {"location": {"type": "geo_point"}},
    },
)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'mta-stations'})

# %% [markdown]
# ### Index the MTA data
#
# We now need to index the data for the MTA.

# %%
import csv

# Download the CSV file
url = "https://data.ny.gov/api/views/39hk-dx4f/rows.csv?accessType=DOWNLOAD"
response = requests.get(url)


# Parse and index the CSV data
def prepare_documents():
    reader = csv.DictReader(response.text.splitlines())
    for row in reader:
        row["location"] = {
            "lat": float(row["GTFS Latitude"]),
            "lon": float(row["GTFS Longitude"]),
        }
        yield {
            "_index": "mta-stations",
            "_source": dict(row),
        }


# Index the documents
helpers.bulk(client, prepare_documents())
# Out:
# (496, [])

# %% [markdown]
# ### Prepare points of interest
#
# Same as before. We want to index the points of interests and use ELSER to make sure that any semantic searches are working. E.g. searching for `sights with gardens` should return `Central Park` even though it does not contain `garden` in the name.

# %%
client.indices.delete(index="points-of-interest", ignore_unavailable=True)
client.indices.create(
    index="points-of-interest",
    settings={"index": {"default_pipeline": "elser-ingest-pipeline"}},
    mappings={
        "dynamic_templates": [
            {
                "stringsaskeywords": {
                    "match": "*",
                    "match_mapping_type": "string",
                    "mapping": {"type": "keyword"},
                }
            }
        ],
        "properties": {
            "NAME": {"type": "text"},
            "location": {"type": "geo_point"},
            "name_embedding": {"type": "sparse_vector"},
        },
    },
)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'points-of-interest'})

# %% [markdown]
# ### Download points of interest
#
# The `the_geom` looks like this: `POINT (-74.00701717096757 40.724634757833414)` which is formatted as a Well-Known Text point format and we officially support this. I personally always like to store my coordinates in lat & lon as an Object to make sure that there are no confusions.

# %%
import csv

# Download the CSV file
url = "https://data.cityofnewyork.us/api/views/t95h-5fsr/rows.csv?accessType=DOWNLOAD"
response = requests.get(url)


# Parse and index the CSV data
def prepare_documents():
    reader = csv.DictReader(response.text.splitlines())
    for row in reader:
        row["location"] = {
            "lat": float(row["the_geom"].split(" ")[2].replace(")", "")),
            "lon": float(row["the_geom"].split(" ")[1].replace("(", "")),
        }
        row["name"] = row["NAME"].lower()
        yield {
            "_index": "points-of-interest",
            "_source": dict(row),
        }


# Index the documents
helpers.bulk(client, prepare_documents(),chunk_size=10)
# Out:
# (20567, [])

# %% [markdown]
# ### Now we have everything prepped
#
# First let's see how well ELSER does with a "geo" query. Let's as it for an AirBnB next to Central Park and Empire State Building. Also we are just looking at the description, not the name or the about author as of now. Let's keep it simple.

# %%
response = client.search(
    index="airbnb-*",
    size=10,
    query={
        "text_expansion": {
            "description_embedding": {
                "model_id": ".elser_model_2",
                "model_text": "Next to Central Park and Empire State Building",
            }
        }
    },
)

for hit in response["hits"]["hits"]:
    doc_id = hit["_id"]
    score = hit["_score"]
    name = hit["_source"]["name"]
    location = hit["_source"]["location"]
    print(
        f"Score: {score}\nTitle: {name}\nLocation: {location}\nDocument ID: {doc_id}\n"
    )
# Out:
# Score: 18.937181
# Title: Midtown Gem!
# Location: {'lon': -73.9809504105621, 'lat': 40.75069179184811}
# Document ID: BVlozY8BHFTyMPLT4Ish
#
# Score: 18.497099
# Title: 2-Bedroom Apartment in Manhattan
# Location: {'lon': -73.98831, 'lat': 40.769}
# Document ID: fFlkzY8BHFTyMPLTCoYx
#
# Score: 18.24646
# Title: 4 Units w/ Impressive City View! Pets Allowed!
# Location: {'lon': -73.9758092977172, 'lat': 40.76538626102478}
# Document ID: bllqzY8BHFTyMPLTMYzH
#
# Score: 18.24646
# Title: Minutes to Central Park Zoo and MoMA! Parking!
# Location: {'lon': -73.97414, 'lat': 40.76354}
# Document ID: pVlnzY8BHFTyMPLTZ4nB
#
# Score: 18.24646
# Title: Central Park Views, Luxury Stay, Pets Are Welcome!
# Location: {'lon': -73.97432, 'lat': 40.76366}
# Document ID: tllnzY8BHFTyMPLTf4me
#
# Score: 18.24646
# Title: Pleasant Stay! Located in the heart of Midtown!
# Location: {'lon': -73.97621, 'lat': 40.76555}
# Document ID: pVlszY8BHFTyMPLTqY5L
#
# Score: 18.24646
# Title: Pleasant Stay! Located in the heart of Midtown!
# Location: {'lon': -73.97430323153209, 'lat': 40.76412781810225}
# Document ID: M1lszY8BHFTyMPLTLY5x
#
# Score: 18.24646
# Title: NYC Midtown Bliss, 4 Pet-Friendly Units!
# Location: {'lon': -73.97634177617803, 'lat': 40.76423824356572}
# Document ID: dVl2zY8BHFTyMPLTM5dg
#
# Score: 18.24646
# Title: Central Park Serenity, 3 Units w/ Panoramic Views!
# Location: {'lon': -73.97635002769093, 'lat': 40.76539801668123}
# Document ID: uVl2zY8BHFTyMPLThZdH
#
# Score: 18.09274
# Title: Convenient apartment in Manhattan
# Location: {'lon': -73.96472, 'lat': 40.79974}
# Document ID: iFlrzY8BHFTyMPLTao2o

# %% [markdown]
# ### Analysing the response
#
# We indexed all AirBnBs, so it might be little different to what you get when you only do the first 5.000.
#
# The next step is to run a geo_distance query within Elasticsearch. First to analyse how far apart `Central Park` and `Empire State Building` is. Since the `Central Park` is pretty big and contains a multitude of points of interest, we will use the `Bow Bridge` an iconic sight.
#
# We will use a simple terms query to get the geo location of `Central Park Bow Bridge` and then run a `geo_distance` query with a `_geo_distance` sort to get the exact distance back. The `geo_distance` query as of now always requires a `distance` parameter. We add a `term` to search for `empire state building` since we are just interested in this.

# %%
response = client.search(
    index="points-of-interest",
    size=1,
    query={"term": {"name": "central park bow bridge"}},
)

for hit in response["hits"]["hits"]:
    # this should now be the central park bow bridge.
    print(f"Name: {hit['_source']['name']}\nLocation: {hit['_source']['location']}\n")
    response = client.search(
        index="points-of-interest",
        size=1,
        query={
            "bool": {
                "must": {"term": {"name": "empire state building"}},
                "filter": {
                    "geo_distance": {
                        "distance": "200km",
                        "location": {
                            "lat": hit["_source"]["location"]["lat"],
                            "lon": hit["_source"]["location"]["lon"],
                        },
                    }
                },
            }
        },
        sort=[
            {
                "_geo_distance": {
                    "location": {
                        "lat": hit["_source"]["location"]["lat"],
                        "lon": hit["_source"]["location"]["lon"],
                    },
                    "unit": "km",
                    "distance_type": "plane",
                    "order": "asc",
                }
            }
        ],
    )
    print(
        f"Distance to Empire State Building: {response['hits']['hits'][0]['sort'][0]} km"
    )
# Out:
# Name: central park bow bridge
# Location: {'lon': -73.97178440451849, 'lat': 40.77577539823907}
#
# Distance to Empire State Building: 3.247504472145157 km

# %% [markdown]
# ### Comparing to Elser
#
# Now our top scoring document:
#
# ```
# Score: 20.003891
# Title: Gorgeous 1 Bedroom - Upper East Side Manhattan -
# Location: {'lon': -73.95856, 'lat': 40.76701}
# Document ID: AkgfEI8BHToGwgcUA6-7
# ```
#
# Let's run the calculation from above using geo_distance.

# %%
response = client.search(
    index="points-of-interest",
    size=10,
    query={
        "bool": {
            "must": {
                "terms": {"name": ["central park bow bridge", "empire state building"]}
            },
            "filter": {
                "geo_distance": {
                    "distance": "200km",
                    "location": {"lat": "40.76701", "lon": "-73.95856"},
                }
            },
        }
    },
    sort=[
        {
            "_geo_distance": {
                "location": {"lat": "40.76701", "lon": "-73.95856"},
                "unit": "km",
                "distance_type": "plane",
                "order": "asc",
            }
        }
    ],
)

for hit in response["hits"]["hits"]:
    print("Distance between AirBnB and", hit["_source"]["name"], hit["sort"][0], "km")
# Out:
# Distance between AirBnB and central park bow bridge 1.4799179352060348 km
# Distance between AirBnB and empire state building 3.0577584374128617 km

# %% [markdown]
# ### Analysing
#
# Only 1.4km and 3km away from the two sights. Not that bad. Let's see what we can find when we create a geo-bounding box with the Empire State Building and the Central Park Bow Bridge. Additionally we will sort the result by the distance to the Central Park Bow Bridge and then by distance to Empire State Building.

# %%
response = client.search(
    index="points-of-interest",
    size=2,
    query={"terms": {"name": ["central park bow bridge", "empire state building"]}},
)

# for easier access we store the locations in two variables
central = {}
empire = {}
for hit in response["hits"]["hits"]:
    hit = hit["_source"]
    if "central park bow bridge" in hit["name"]:
        central = hit["location"]
    elif "empire state building" in hit["name"]:
        empire = hit["location"]

# Now we can run the geo_bounding_box query and sort it by the
# distance first to Central Park Bow Bridge
# and then to the Empire State Building.
response = client.search(
    index="airbnb-*",
    size=50,
    query={
        "geo_bounding_box": {
            "location": {
                "top_left": {"lat": central["lat"], "lon": empire["lon"]},
                "bottom_right": {"lat": empire["lat"], "lon": central["lon"]},
            }
        }
    },
    sort=[
        {
            "_geo_distance": {
                "location": {"lat": central["lat"], "lon": central["lon"]},
                "unit": "km",
                "distance_type": "plane",
                "order": "asc",
            }
        },
        {
            "_geo_distance": {
                "location": {"lat": empire["lat"], "lon": empire["lon"]},
                "unit": "km",
                "distance_type": "plane",
                "order": "asc",
            }
        },
    ],
)

for hit in response["hits"]["hits"]:
    print(f"Distance to Central Park Bow Bridge: {hit['sort'][0]} km")
    print(f"Distance to Empire State Building: {hit['sort'][1]} km")
    print(f"Title: {hit['_source']['name']}\nDocument ID: {hit['_id']}\n")
# Out:
# Distance to Central Park Bow Bridge: 0.7522774827930032 km
# Distance to Empire State Building: 2.788981551632797 km
# Title: Shared room at Lincoln Center
# Document ID: b1lzzY8BHFTyMPLTt5UM
#
# Distance to Central Park Bow Bridge: 0.8285887310207944 km
# Distance to Empire State Building: 2.654302842845152 km
# Title: Blueground | UWS, w/d, nr Lincon Center
# Document ID: TFljzY8BHFTyMPLTv4bj
#
# Distance to Central Park Bow Bridge: 0.9179057084098068 km
# Distance to Empire State Building: 2.633649076174077 km
# Title: Manhattan New York Upper West side
# Document ID: YlllzY8BHFTyMPLT7Ig9
#
# Distance to Central Park Bow Bridge: 1.1243476248351183 km
# Distance to Empire State Building: 2.4285558932557834 km
# Title: Luxury 3 BR condo + balcony w views of Central PK
# Document ID: O1ljzY8BHFTyMPLTtIb7
#
# Distance to Central Park Bow Bridge: 1.1712213104190234 km
# Distance to Empire State Building: 2.2972489327173635 km
# Title: Upper West Apartment Block Away from Central Park!
# Document ID: MVlzzY8BHFTyMPLTeJWm
#
# Distance to Central Park Bow Bridge: 1.1965367009108774 km
# Distance to Empire State Building: 2.052637580582263 km
# Title: Pleasant Stay! Located in the heart of Midtown!
# Document ID: pVlszY8BHFTyMPLTqY5L
#
# Distance to Central Park Bow Bridge: 1.203920763104975 km
# Distance to Empire State Building: 2.048724653385503 km
# Title: 4 Units w/ Impressive City View! Pets Allowed!
# Document ID: bllqzY8BHFTyMPLTMYzH
#
# Distance to Central Park Bow Bridge: 1.2162865943236207 km
# Distance to Empire State Building: 2.0325557089978865 km
# Title: Central Park Serenity, 3 Units w/ Panoramic Views!
# Document ID: uVl2zY8BHFTyMPLThZdH
#
# Distance to Central Park Bow Bridge: 1.2284883745914836 km
# Distance to Empire State Building: 2.0202502743639057 km
# Title: Lux Studio, W 58th, 24/7 Onsite Team
# Document ID: Y1l2zY8BHFTyMPLTHpev
#
# Distance to Central Park Bow Bridge: 1.2293811749593695 km
# Distance to Empire State Building: 2.0245765775863642 km
# Title: Blueground | Midtown, doorman, nr Central Park
# Document ID: l1l3zY8BHFTyMPLTd5jz
#
# Distance to Central Park Bow Bridge: 1.2532794670159673 km
# Distance to Empire State Building: 2.198540522722834 km
# Title: Central Park view from the Mandarin hôtel
# Document ID: ClltzY8BHFTyMPLTJo-G
#
# Distance to Central Park Bow Bridge: 1.2958879642140237 km
# Distance to Empire State Building: 1.9765226498576123 km
# Title: High Ceilings Central 1-bed Loft/Washer&Dryer
# Document ID: qlluzY8BHFTyMPLT65DB
#
# Distance to Central Park Bow Bridge: 1.3124131686746086 km
# Distance to Empire State Building: 1.9770054204252814 km
# Title: Pleasant Stay! Located in the heart of Midtown!
# Document ID: M1lszY8BHFTyMPLTLY5x
#
# Distance to Central Park Bow Bridge: 1.3149975830256424 km
# Distance to Empire State Building: 1.932570906644294 km
# Title: The Quin By Hilton - 1 Bedroom Premier
# Document ID: D1l2zY8BHFTyMPLT6Jjd
#
# Distance to Central Park Bow Bridge: 1.3223138078589027 km
# Distance to Empire State Building: 1.9547695716799907 km
# Title: Central Park -  5 Star Hotel - 1 Bed 2 Bath
# Document ID: PVljzY8BHFTyMPLTtIb7
#
# Distance to Central Park Bow Bridge: 1.3233391471465499 km
# Distance to Empire State Building: 2.0227741004518083 km
# Title: Stylish, modern and comfy 1 Bdrm
# Document ID: w1lrzY8BHFTyMPLTr41o
#
# Distance to Central Park Bow Bridge: 1.3390567707704621 km
# Distance to Empire State Building: 1.9137182051913784 km
# Title: NYC Midtown Bliss, 4 Pet-Friendly Units!
# Document ID: dVl2zY8BHFTyMPLTM5dg
#
# Distance to Central Park Bow Bridge: 1.36399196962037 km
# Distance to Empire State Building: 1.9305553018370814 km
# Title: Central Park Views, Luxury Stay, Pets Are Welcome!
# Document ID: tllnzY8BHFTyMPLTf4me
#
# Distance to Central Park Bow Bridge: 1.3749063425421144 km
# Distance to Empire State Building: 1.9262279427800975 km
# Title: Minutes to Central Park Zoo and MoMA! Parking!
# Document ID: pVlnzY8BHFTyMPLTZ4nB
#
# Distance to Central Park Bow Bridge: 1.3839932672748814 km
# Distance to Empire State Building: 1.8830186724555626 km
# Title: Shoreham Hotel - Chic Room in Midtown Manhattan
# Document ID: OFltzY8BHFTyMPLTXI8r
#
# Distance to Central Park Bow Bridge: 1.388024680828252 km
# Distance to Empire State Building: 1.876524232528267 km
# Title: Shoreham Hotel - Touchless Petite Unit in NYC
# Document ID: zllmzY8BHFTyMPLTV4iM
#
# Distance to Central Park Bow Bridge: 1.3979667837385543 km
# Distance to Empire State Building: 1.8737650935475079 km
# Title: Shoreham Hotel - Petite Unit Close to Landmarks
# Document ID: 0VlmzY8BHFTyMPLTV4iM
#
# Distance to Central Park Bow Bridge: 1.3989630467498075 km
# Distance to Empire State Building: 1.8693984480425594 km
# Title: Shoreham Hotel - Petite Hip Unit near Central Park
# Document ID: zVlmzY8BHFTyMPLTV4iM
#
# Distance to Central Park Bow Bridge: 1.4191868794412774 km
# Distance to Empire State Building: 1.8458188785729415 km
# Title: Shoreham Hotel - Petite Room with Queen Bed
# Document ID: yVlmzY8BHFTyMPLTUIhn
#
# Distance to Central Park Bow Bridge: 1.4193617315573501 km
# Distance to Empire State Building: 1.8508349682507874 km
# Title: Shoreham Hotel - Petite Room in Midtown Manhattan
# Document ID: w1lmzY8BHFTyMPLTUIhn
#
# Distance to Central Park Bow Bridge: 1.4245590234185257 km
# Distance to Empire State Building: 1.8362410283266397 km
# Title: One Bedroom Deluxe Suite - Accessible / Weekly
# Document ID: 41l2zY8BHFTyMPLTvZfg
#
# Distance to Central Park Bow Bridge: 1.4266175882443883 km
# Distance to Empire State Building: 1.843360342318166 km
# Title: Shoreham Hotel - Petite Touchless Hip Unit
# Document ID: wllozY8BHFTyMPLTnorQ
#
# Distance to Central Park Bow Bridge: 1.4298823891346428 km
# Distance to Empire State Building: 1.8233288276841388 km
# Title: Shoreham Hotel - Modern Unit right in NYC!
# Document ID: yFlmzY8BHFTyMPLTUIhn
#
# Distance to Central Park Bow Bridge: 1.430142323461669 km
# Distance to Empire State Building: 1.9249539405177045 km
# Title: The Manhattan club
# Document ID: bFlkzY8BHFTyMPLT8YcS
#
# Distance to Central Park Bow Bridge: 1.4334602418443978 km
# Distance to Empire State Building: 1.814927765784435 km
# Title: Shoreham Hotel - Cozy Unit in the heart of NYC
# Document ID: 1FlmzY8BHFTyMPLTV4iM
#
# Distance to Central Park Bow Bridge: 1.4373518670999113 km
# Distance to Empire State Building: 1.9371785310761407 km
# Title: Cozy 2 Beds 1 Bath Apartment in Midtown Manhattan
# Document ID: N1ljzY8BHFTyMPLTqIYc
#
# Distance to Central Park Bow Bridge: 1.4459703637812542 km
# Distance to Empire State Building: 1.8016929975134535 km
# Title: Quin Hotel Studio in Manhattan
# Document ID: LFltzY8BHFTyMPLTUI8O
#
# Distance to Central Park Bow Bridge: 1.4460180868723462 km
# Distance to Empire State Building: 1.803008545155031 km
# Title: Shoreham Hotel - Contemporary Room in Midtown
# Document ID: I1ltzY8BHFTyMPLTRo-k
#
# Distance to Central Park Bow Bridge: 1.4483924511736832 km
# Distance to Empire State Building: 1.8609641215825754 km
# Title: Two Bathroom Suite steps from Central Park
# Document ID: 6Vl2zY8BHFTyMPLTvZfg
#
# Distance to Central Park Bow Bridge: 1.462277569713158 km
# Distance to Empire State Building: 1.8130035187195017 km
# Title: Hotel Living @ 'The Manhattan Club'
# Document ID: RllyzY8BHFTyMPLTVJSq
#
# Distance to Central Park Bow Bridge: 1.4673493673919455 km
# Distance to Empire State Building: 1.8887248836382509 km
# Title: Luxe 2-bed in Hell's Kitchen
# Document ID: 3FlozY8BHFTyMPLTs4qS
#
# Distance to Central Park Bow Bridge: 1.4682455876599063 km
# Distance to Empire State Building: 1.8663534328224805 km
# Title: Lovely apt at the Best location in Manhattan 😃👏🏼
# Document ID: j1l3zY8BHFTyMPLTbJho
#
# Distance to Central Park Bow Bridge: 1.4682640198968937 km
# Distance to Empire State Building: 2.085195919136176 km
# Title: Central Park 근처 안전한 위치에 New renovated 2 베드룸+1 어린이룸
# Document ID: mFl3zY8BHFTyMPLTd5jz
#
# Distance to Central Park Bow Bridge: 1.4688577765961266 km
# Distance to Empire State Building: 1.7796596183346314 km
# Title: Shoreham Hotel | Spacious Studio near Central Park
# Document ID: Q1llzY8BHFTyMPLTyIjS
#
# Distance to Central Park Bow Bridge: 1.473667496779013 km
# Distance to Empire State Building: 1.8039143434511709 km
# Title: Shoreham Hotel - Dainty Unit in Midtown Manhattan!
# Document ID: H1lpzY8BHFTyMPLT6oyB
#
# Distance to Central Park Bow Bridge: 1.4811009626874592 km
# Distance to Empire State Building: 1.7674718085139172 km
# Title: Spacious Alcove Studio near Rockefeller Center
# Document ID: WVlkzY8BHFTyMPLT34c7
#
# Distance to Central Park Bow Bridge: 1.4904547521693772 km
# Distance to Empire State Building: 1.956441234866712 km
# Title: Studio in Manhattan
# Document ID: 8VlozY8BHFTyMPLTyorb
#
# Distance to Central Park Bow Bridge: 1.4936126621490002 km
# Distance to Empire State Building: 1.7549932957092287 km
# Title: Shoreham Hotel - Comfortable Unit in Midtown
# Document ID: x1lmzY8BHFTyMPLTUIhn
#
# Distance to Central Park Bow Bridge: 1.4943441849042296 km
# Distance to Empire State Building: 2.021068635492903 km
# Title: Beautiful One Bedroom Apartment
# Document ID: 3llxzY8BHFTyMPLTC5KW
#
# Distance to Central Park Bow Bridge: 1.4969594390933907 km
# Distance to Empire State Building: 1.7522979410089314 km
# Title: Shoreham Hotel - Modern Unit near Times Square
# Document ID: HVlpzY8BHFTyMPLT44xS
#
# Distance to Central Park Bow Bridge: 1.5014084647133614 km
# Distance to Empire State Building: 1.8965334818213662 km
# Title: Luxury building studio apartment
# Document ID: FFlozY8BHFTyMPLT8Ys2
#
# Distance to Central Park Bow Bridge: 1.5071366420331809 km
# Distance to Empire State Building: 1.7710546225821397 km
# Title: St Regis Hotel, NYC Luxury Hotel Rooms by Owners
# Document ID: v1lnzY8BHFTyMPLTiYnz
#
# Distance to Central Park Bow Bridge: 1.508412635400453 km
# Distance to Empire State Building: 2.0119425478113033 km
# Title: Spacious Room in The Heart of Manhattan
# Document ID: UlltzY8BHFTyMPLTcI-C
#
# Distance to Central Park Bow Bridge: 1.5124156520425913 km
# Distance to Empire State Building: 1.9610805181995796 km
# Title: Beautiful Garden View Sanctuary near Central Park
# Document ID: PFljzY8BHFTyMPLTtIb7
#
# Distance to Central Park Bow Bridge: 1.5209791561302863 km
# Distance to Empire State Building: 1.8849156445746391 km
# Title: Cozy apartment in Downtown NYC
# Document ID: UVl3zY8BHFTyMPLTMZj4

# %% [markdown]
# ## AI
#
# Now let's finally get to the AI part. All of this was the setup and understanding what makes geo spatial searches tick and how they work. There is still a lot more to discover. Let's hookup it up to our OpenAI instance.

# %%
from openai import OpenAI

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# Set API key
openai = OpenAI()

# Let's do a test:
question = "What is the capital of France? Answer with just the capital city."

answer = openai.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": question,
        }
    ],
    model="gpt-3.5-turbo",
)

print(answer.choices[0].message.content)
# Out:
# Paris

# %% [markdown]
# Now that this works, we are sure that we are in the correct place to start our question. We are writing a prompt that forces ChatGPT to create a JSON response and extract the information from the question.

# %%
question = """
As an expert in named entity recognition machine learning models, I will give you a sentence from which I would like you to extract what needs to be found (location, apartment, airbnb, sight, etc) near which location and the distance between them. The distance needs to be a number expressed in kilometers. I would like the result to be expressed in JSON with the following fields: "what", "near", "distance_in_km". Only return the JSON.
Here is the sentence: "Get me the closest AirBnB between 1 miles distance from the Empire State Building"
"""

answer = openai.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": question,
        }
    ],
    model="gpt-3.5-turbo",
)
print(answer.choices[0].message.content)
# Out:
# {
#   "what": "AirBnB",
#   "near": "Empire State Building",
#   "distance_in_km": 1.6
# }

# %% [markdown]
# The answer in our case is the following
#
# Here is the desired output:
# ```
# {
#     "what": "AirBnB",
#     "near": "Empire State Building",
#     "distance_in_km": 1610
# }
# ```
# 1) Extract distance - done (1 miles)
# 2) Convert distance to km - done (1.6 km)
# 3) Extract location - This should be "Empire State Building", but in more general terms we should recognize that this is a location so we make a separate label called

# %%
json = answer.choices[0].message.content
# This now should contain just the json.
json = JSON.loads(json)

# first let's grab the location of the `near` field
# it could be multiple locations, so we will search for all of them.
near = client.search(
    index="points-of-interest",
    size=100,
    query={"bool": {"must": {"terms": {"name": [json["near"].lower()]}}}},
)

# we store just all of the geo-locations of the near locations.
near_location = []
sort = []

for hit in near["hits"]["hits"]:
    near_location.append(hit["_source"]["location"])
    sort.append(
        {
            "_geo_distance": {
                "location": {
                    "lat": hit["_source"]["location"]["lat"],
                    "lon": hit["_source"]["location"]["lon"],
                },
                "unit": "km",
                "distance_type": "plane",
                "order": "asc",
            }
        }
    )

query = {
    "geo_distance": {
        "distance": str(json["distance_in_km"]) + "km",
        "location": {"lat": near_location[0]["lat"], "lon": near_location[0]["lon"]},
    }
}
# Now let's get all the AirBnBs `what` near the `near` location.
# We always use the first location as our primary reference.
airbnbs = client.search(index="airbnb-*", size=100, query=query, sort=sort)

for hit in airbnbs["hits"]["hits"]:
    print(f"Distance to {json['near']}: {hit['sort'][0]} km")
    print(f"Title: {hit['_source']['name']}\nDocument ID: {hit['_id']}\n")
# Out:
# Distance to Empire State Building: 0.07179165027056177 km
# Title: Gorgeous 1 bedroom luxury condo
# Document ID: mlllzY8BHFTyMPLTHIen
#
# Distance to Empire State Building: 0.11711484106305878 km
# Title: Exclusive Private Studio 1103 | Private Bathroom
# Document ID: 91lmzY8BHFTyMPLTjojD
#
# Distance to Empire State Building: 0.11786577229462668 km
# Title: Room available in Midtown
# Document ID: fFlwzY8BHFTyMPLTs5Ie
#
# Distance to Empire State Building: 0.12218665438647491 km
# Title: A+ Location Deluxe Studio(3 beds) #5
# Document ID: 9llozY8BHFTyMPLT1orX
#
# Distance to Empire State Building: 0.1361089243182925 km
# Title: Easy access to transit for seeing all the sights
# Document ID: Z1lwzY8BHFTyMPLTmZKx
#
# Distance to Empire State Building: 0.1361089243182925 km
# Title: Well appointed queen with ADA features
# Document ID: xllwzY8BHFTyMPLTBpHL
#
# Distance to Empire State Building: 0.14812006828137478 km
# Title: Cozy Scandinavian private room in Midtown
# Document ID: P1lzzY8BHFTyMPLTgpWk
#
# Distance to Empire State Building: 0.1492540503440509 km
# Title: A+ Location Comfort Lofty & Bright Queen Studio #5
# Document ID: DFlxzY8BHFTyMPLTN5Pw
#
# Distance to Empire State Building: 0.15225274311294673 km
# Title: Near Times Square & Central Park! 3 Deluxe Units!
# Document ID: FFlvzY8BHFTyMPLTTpHa
#
# Distance to Empire State Building: 0.1543975924221713 km
# Title: Your Own Studio Room Prime Midtown N833
# Document ID: JVlmzY8BHFTyMPLTv4my
#
# Distance to Empire State Building: 0.15891724131853355 km
# Title: Centered location Manhattan* 5th floor * 5 people
# Document ID: YlljzY8BHFTyMPLT7IZR
#
# Distance to Empire State Building: 0.16162905671575786 km
# Title: Exclusive Private Duplex 862 | Private Bathroom
# Document ID: C1lxzY8BHFTyMPLTN5Pw
#
# Distance to Empire State Building: 0.16663819740710875 km
# Title: A+ Location Comfort Stay Studio (3 Beds) #3
# Document ID: KFltzY8BHFTyMPLTRo-k
#
# Distance to Empire State Building: 0.17737324872138946 km
# Title: Rare Gem! Near Museum of Modern Art
# Document ID: RVljzY8BHFTyMPLTv4bj
#
# Distance to Empire State Building: 0.1930099351101457 km
# Title: Look No More! Pets Allowed HERE!
# Document ID: RFljzY8BHFTyMPLTv4bj
#
# Distance to Empire State Building: 0.21528159408058442 km
# Title: Luxe bath with marble counters, robes & slippers
# Document ID: 3llwzY8BHFTyMPLTIpHa
#
# Distance to Empire State Building: 0.2352564175134252 km
# Title: Big beautiful apartment near Empire State Building
# Document ID: A1ltzY8BHFTyMPLTJo-G
#
# Distance to Empire State Building: 0.23850644907197285 km
# Title: Lovely 1Bedroom in 2 Bedroom available
# Document ID: gFlwzY8BHFTyMPLTv5KI
#
# Distance to Empire State Building: 0.24546327413981398 km
# Title: Experience NYC Like Never Before! Pet-friendly!
# Document ID: iFlzzY8BHFTyMPLTy5Vu
#
# Distance to Empire State Building: 0.24614750483328215 km
# Title: Queen Room Terrace
# Document ID: dllwzY8BHFTyMPLTs5Ie
#
# Distance to Empire State Building: 0.25202393376711707 km
# Title: Beautiful Room available
# Document ID: pVlkzY8BHFTyMPLTPoZf
#
# Distance to Empire State Building: 0.264984703356829 km
# Title: Studio apt in nyc
# Document ID: NllozY8BHFTyMPLTEIpJ
#
# Distance to Empire State Building: 0.26827490581740004 km
# Title: Beautiful 1Bedroom in 2Bedroom Apt in Midtown
# Document ID: rllvzY8BHFTyMPLT7pH1
#
# Distance to Empire State Building: 0.2691821200083601 km
# Title: Midtown South 1 BR w/ Office by Anyplace - 11607
# Document ID: 01lmzY8BHFTyMPLTV4iM
#
# Distance to Empire State Building: 0.2712799772130416 km
# Title: Your Own Studio Room Prime Midtown N406
# Document ID: qllmzY8BHFTyMPLTNYhO
#
# Distance to Empire State Building: 0.273558045481475 km
# Title: Heart of Manhattan Midtown!!(Herald Square)
# Document ID: jVlyzY8BHFTyMPLTqJSd
#
# Distance to Empire State Building: 0.2739021265394857 km
# Title: CENTERED LOCATION*6TH FLOOR*STUDIO FOR 4 PEOPLE
# Document ID: yllqzY8BHFTyMPLTpYxj
#
# Distance to Empire State Building: 0.28211771067025165 km
# Title: A + Location Superior 3 Beds Studio
# Document ID: I1llzY8BHFTyMPLTp4hm
#
# Distance to Empire State Building: 0.2869919621060169 km
# Title: 3 Full Beds, next to Korea-town, Times Square4
# Document ID: CllxzY8BHFTyMPLTN5Pw
#
# Distance to Empire State Building: 0.2996099815623641 km
# Title: Chambre au coeur de Manhattan
# Document ID: G1lyzY8BHFTyMPLTJ5TL
#
# Distance to Empire State Building: 0.30179758633621173 km
# Title: Executive loft near Penn Station
# Document ID: AllmzY8BHFTyMPLTnYk6
#
# Distance to Empire State Building: 0.3046495637034873 km
# Title: Studio631 In the heart of Midtown Manhattan
# Document ID: VFljzY8BHFTyMPLTzYZU
#
# Distance to Empire State Building: 0.3113289761991972 km
# Title: New york Multi-unit building
# Document ID: ZFlozY8BHFTyMPLTOIo-
#
# Distance to Empire State Building: 0.31380189160692246 km
# Title: Elegant Studio
# Document ID: 11lnzY8BHFTyMPLTpIkD
#
# Distance to Empire State Building: 0.3332113957651838 km
# Title: The Herald 8 by LuxUrban, Double Beds
# Document ID: k1llzY8BHFTyMPLTE4dd
#
# Distance to Empire State Building: 0.33881234601400345 km
# Title: Midtown South Lux Large Studio
# Document ID: xFl0zY8BHFTyMPLTIJVE
#
# Distance to Empire State Building: 0.34424664108892783 km
# Title: Midtown Elegant Corner Loft  With  Great Views #89
# Document ID: 21lqzY8BHFTyMPLTsow0
#
# Distance to Empire State Building: 0.3474702766490678 km
# Title: The Epic: Right by MSG
# Document ID: CllozY8BHFTyMPLT6It3
#
# Distance to Empire State Building: 0.3508725818857317 km
# Title: Cozy 1BR Apartment in NYC!
# Document ID: KFlrzY8BHFTyMPLTCo1U
#
# Distance to Empire State Building: 0.3522032205767895 km
# Title: Chelsea luxury apartment
# Document ID: yllkzY8BHFTyMPLTYYZN
#
# Distance to Empire State Building: 0.35231381549641655 km
# Title: National at 888 Sixth Avenue - Studio
# Document ID: 0llmzY8BHFTyMPLTV4iM
#
# Distance to Empire State Building: 0.3529843729949807 km
# Title: Spacious private room in a private rental #7
# Document ID: -VluzY8BHFTyMPLTLI_H
#
# Distance to Empire State Building: 0.3538946522815024 km
# Title: Private Room 1423 | Share Bath
# Document ID: dVlszY8BHFTyMPLTbI7j
#
# Distance to Empire State Building: 0.37247660152302997 km
# Title: Exclusive Private Room 619 | Shared Bathroom Only
# Document ID: 6VlxzY8BHFTyMPLTFJIe
#
# Distance to Empire State Building: 0.3749534205139276 km
# Title: Room with shared bathroom 509
# Document ID: 7lluzY8BHFTyMPLTIY87
#
# Distance to Empire State Building: 0.3816137235461938 km
# Title: Guest Room King Bed at Madison Square Garden
# Document ID: 61lmzY8BHFTyMPLTfojD
#
# Distance to Empire State Building: 0.3818805230443256 km
# Title: Bryant Park Studio 3
# Document ID: hFlvzY8BHFTyMPLTx5Hp
#
# Distance to Empire State Building: 0.3886508726734082 km
# Title: Great One Bedroom  Apartment Next  Empire State #8
# Document ID: GVluzY8BHFTyMPLTT5A8
#
# Distance to Empire State Building: 0.39343662982755523 km
# Title: Studio 3 blocks from Empire State Building
# Document ID: fllrzY8BHFTyMPLTX40v
#
# Distance to Empire State Building: 0.4067750660556799 km
# Title: Gorgeous 1Br in the heart of NoMad
# Document ID: 41lmzY8BHFTyMPLTb4j-
#
# Distance to Empire State Building: 0.40922407675655637 km
# Title: Quad Room with 2 Double beds. Room 306
# Document ID: Q1ljzY8BHFTyMPLTv4bj
#
# Distance to Empire State Building: 0.41405006325559035 km
# Title: Cozy Private Room in the Heart of New York City!
# Document ID: wlltzY8BHFTyMPLT-Y_k
#
# Distance to Empire State Building: 0.4293902632060302 km
# Title: Quad room with private bath-706
# Document ID: CFlqzY8BHFTyMPLT4409
#
# Distance to Empire State Building: 0.43439876954261214 km
# Title: Hotel 32 32, Queen Superior
# Document ID: RFlvzY8BHFTyMPLTgJFA
#
# Distance to Empire State Building: 0.43542201101095634 km
# Title: A nod to nostalgia & local whiskey in the minibar
# Document ID: qVlkzY8BHFTyMPLTR4aj
#
# Distance to Empire State Building: 0.4437063104199105 km
# Title: Cozy/Comfortable/Clean, 3 Bedroom/2 Bathroom
# Document ID: bFlwzY8BHFTyMPLTppKE
#
# Distance to Empire State Building: 0.44573958775522393 km
# Title: Double room with attached bathroom -707
# Document ID: Y1lszY8BHFTyMPLTY47B
#
# Distance to Empire State Building: 0.4460114020989568 km
# Title: Midtown Gem!
# Document ID: BVlozY8BHFTyMPLT4Ish
#
# Distance to Empire State Building: 0.44875267944737113 km
# Title: Double Room with shared bath, Room has wash basin.
# Document ID: 31lqzY8BHFTyMPLTvIxj
#
# Distance to Empire State Building: 0.45973915793362163 km
# Title: Blueground | Murray Hill, gym, nr library
# Document ID: h1lvzY8BHFTyMPLTx5Hp
#
# Distance to Empire State Building: 0.4730519744026168 km
# Title: Royalton Park Avenue, Manhattan Suite!
# Document ID: illwzY8BHFTyMPLTy5KM
#
# Distance to Empire State Building: 0.4748384408811902 km
# Title: Midtown East Master Bedroom
# Document ID: M1lyzY8BHFTyMPLTP5Qn
#
# Distance to Empire State Building: 0.502612943921097 km
# Title: Beautiful Studio on Park Avenue
# Document ID: AVlvzY8BHFTyMPLTQpFW
#
# Distance to Empire State Building: 0.517169447441453 km
# Title: Sonder Flatiron | Queen Room
# Document ID: kllwzY8BHFTyMPLT1JJ2
#
# Distance to Empire State Building: 0.5187781523317776 km
# Title: Sunny room in the heart of NYC
# Document ID: l1lpzY8BHFTyMPLTbYsE
#
# Distance to Empire State Building: 0.5360332751831509 km
# Title: Chic 3BD Apart NoMad Manhattan
# Document ID: kVlqzY8BHFTyMPLTXYwk
#
# Distance to Empire State Building: 0.5367207942089818 km
# Title: PLEASE REMOVE MY LISTING! NO LONGER AVAILABLE!
# Document ID: 31lpzY8BHFTyMPLTrIvE
#
# Distance to Empire State Building: 0.5377012096919607 km
# Title: Skylight Studio in Chelsea
# Document ID: EFluzY8BHFTyMPLTQpAh
#
# Distance to Empire State Building: 0.543316995145414 km
# Title: Best view of the Empire State in all NYC!
# Document ID: DFlwzY8BHFTyMPLTRZKm
#
# Distance to Empire State Building: 0.5441983788608815 km
# Title: Close to all best locations
# Document ID: Q1luzY8BHFTyMPLTi5Ap
#
# Distance to Empire State Building: 0.5461858449871614 km
# Title: Prime location walk to all
# Document ID: 4llnzY8BHFTyMPLTr4mT
#
# Distance to Empire State Building: 0.5549468762543348 km
# Title: Comfortable Midtown Bedroom
# Document ID: MVlvzY8BHFTyMPLTbZEe
#
# Distance to Empire State Building: 0.5559849827503454 km
# Title: Murray Hill studio
# Document ID: aFlozY8BHFTyMPLTQorZ
#
# Distance to Empire State Building: 0.5615947052381932 km
# Title: SEXY Grand Central Modern CHIC BRAND NEW PARK AVE
# Document ID: VFlszY8BHFTyMPLTTo5L
#
# Distance to Empire State Building: 0.5655229689395729 km
# Title: No longer available
# Document ID: e1lzzY8BHFTyMPLTwJWp
#
# Distance to Empire State Building: 0.575665327588923 km
# Title: Your Home Away From Home! Dog-friendly
# Document ID: dVlkzY8BHFTyMPLT-IeA
#
# Distance to Empire State Building: 0.5907870435850854 km
# Title: Spacious Midtown-East Bedroom/Apt
# Document ID: RllwzY8BHFTyMPLTepJo
#
# Distance to Empire State Building: 0.6114138997907826 km
# Title: midtown apartment
# Document ID: H1lxzY8BHFTyMPLTRpNa
#
# Distance to Empire State Building: 0.6132611071915768 km
# Title: 1-Bedroom Hotel Suite - 2 beds
# Document ID: HllkzY8BHFTyMPLTqofb
#
# Distance to Empire State Building: 0.6156131407890929 km
# Title: Stylishly Decorated Two Bedroom near Empire State
# Document ID: _VluzY8BHFTyMPLTNY9y
#
# Distance to Empire State Building: 0.6175676036613298 km
# Title: Cozy 1 Bedroom Jr. / Park Ave.
# Document ID: JFltzY8BHFTyMPLTRo-k
#
# Distance to Empire State Building: 0.6290100102263518 km
# Title: Single  Room with Shared bath  #504
# Document ID: -FluzY8BHFTyMPLTLI_H
#
# Distance to Empire State Building: 0.6314344651451544 km
# Title: Beautiful Chelsea One Bedroom in Great Location
# Document ID: A1luzY8BHFTyMPLTNZBy
#
# Distance to Empire State Building: 0.6358143126255036 km
# Title: Amazing and Large Modern Studio
# Document ID: BllwzY8BHFTyMPLTRZKm
#
# Distance to Empire State Building: 0.6368920431188196 km
# Title: Double room with private bath -608
# Document ID: d1lrzY8BHFTyMPLTV42X
#
# Distance to Empire State Building: 0.6388605768858097 km
# Title: Large Center Manhattan Studio
# Document ID: 9VlozY8BHFTyMPLT1orX
#
# Distance to Empire State Building: 0.6428103973806202 km
# Title: Double Room with Private bath.
# Document ID: OlljzY8BHFTyMPLTtIb7
#
# Distance to Empire State Building: 0.6544153320915234 km
# Title: Contemporary One Bedroom walking distance to High
# Document ID: JFluzY8BHFTyMPLTXJCA
#
# Distance to Empire State Building: 0.656586732235225 km
# Title: Quad Room 201
# Document ID: 6llvzY8BHFTyMPLTHpAG
#
# Distance to Empire State Building: 0.6700253969045458 km
# Title: Comfortable room in Times Square
# Document ID: OllpzY8BHFTyMPLTFYst
#
# Distance to Empire State Building: 0.6711604351979287 km
# Title: Impeccable Midtown one bedroom apartment
# Document ID: hFlkzY8BHFTyMPLTFYZK
#
# Distance to Empire State Building: 0.6717018851464982 km
# Title: Chic Midtown Room
# Document ID: lVlwzY8BHFTyMPLT1JJ2
#
# Distance to Empire State Building: 0.6726028027438895 km
# Title: Entire Luxury studio in the heart of Manhattan
# Document ID: dVlmzY8BHFTyMPLTAYie
#
# Distance to Empire State Building: 0.6748840582994585 km
# Title: 3rd Floor 2 Bedroom by Park Ave
# Document ID: nVlszY8BHFTyMPLTnI68
#
# Distance to Empire State Building: 0.6769134881572337 km
# Title: Furnished one bedroom beauty in midtown NYC
# Document ID: IllszY8BHFTyMPLTGY4r
#
# Distance to Empire State Building: 0.6782546440039858 km
# Title: Murray Hill one bedroom Gem
# Document ID: 3VluzY8BHFTyMPLTDo9C
#
# Distance to Empire State Building: 0.6792265702831013 km
# Title: Stylish ROOM in Manhattan
# Document ID: NVljzY8BHFTyMPLTqIYc
#
# Distance to Empire State Building: 0.6825787093010492 km
# Title: Comfy Bedroom in Prime Manhattan
# Document ID: q1lkzY8BHFTyMPLTR4aj
#
# Distance to Empire State Building: 0.6844795179943811 km
# Title: NYC Studio Apartment
# Document ID: K1lyzY8BHFTyMPLTP5Qn
#
# Distance to Empire State Building: 0.6845318504369667 km
# Title: Kips Bay hideaway
# Document ID: T1lkzY8BHFTyMPLT14cC

# %% [markdown]
# With that we now have combined geo spatial search with LLMs.
#
# Some idea for further exploration:
# * Let any LLM generate an itinerary with sights.
# ...
